# %% [markdown]
# # Preprocess SCOPe data PDB files

# %% [markdown]
# In this code, PDB files from the SCOPe database (url : https://scop.berkeley.edu/ are downloaded and preprocessed before it can be used for analyses. The proteins that are not single chain topologies and contain more than 200 frames are filtered out. Consequently, the hydrogen atoms are removed and residues are renumbered and only the lines not starting with 'ATOM' are removed.
#
# Data is saved in the CT_code/PDB_files_preparation/output/pdbs_traj/SCOPe_single_chain' and can be copied to the protein_CT/input folder by running the last block of code.

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import requests
import os
import mdtraj
import tarfile
import shutil
from requests import get

# %% [markdown]
# ## Function to renumber residues

# %%
def renumber_residues(folder_path, start_residue_number):
    
#Function to renumber all incorrectly numbered residues from trajectory folder. 
    for filename in os.listdir(folder_path):
        if filename.endswith('.pdb'):
            input_pdb = os.path.join(folder_path, filename)
    
            with open(input_pdb, 'r') as infile:
                lines = infile.readlines()
            
            # Check the residue number in the first ATOM/HETATM line
            first_residue_number = None
            for line in lines:
                if line.startswith(("ATOM", "HETATM")):
                    first_residue_number = int(line[22:26].strip())
                    break
            
            # Only proceed with renumbering if the first residue is 9999 (-1) or 0
            if first_residue_number != 1:
                with open(input_pdb, 'w') as outfile:
                    current_residue_number = start_residue_number
                    last_residue_id = None
                    first_residue = True  # Flag to handle the first residue separately

                    for line in lines:
                        # Only renumber residue information in ATOM/HETATM records
                        if line.startswith(("ATOM", "HETATM")):
                            residue_id = line[22:26].strip()

                            # Check if we're on a new residue
                            if residue_id != last_residue_id:
                                last_residue_id = residue_id
                                # Increment only after the first residue
                                if not first_residue:
                                    current_residue_number += 1
                                first_residue = False  # Set flag to False after first residue

                            # Replace residue number in the line
                            new_line = (
                                line[:22] +
                                "{:4}".format(current_residue_number) +  # Format the new residue number
                                line[26:]
                            )
                            outfile.write(new_line)
                        else:
                            # Write non-ATOM/HETATM lines as is
                            outfile.write(line)
        
                print("Residues renumbered successfully in {}".format(input_pdb))
            else:
                print("Skipped renumbering for {} (first residue is already 1)".format(filename))

# %% [markdown]
# ## Download each pdb file from web URL

# %% [markdown]
# From the SCOPe database, one protein from every number of folds is taken, which can be filtered using the following linkes. To see all protein classes: https://scop.berkeley.edu/statistics/ver=2.08
# To download the corresponding sid numbers to folds: https://scop.berkeley.edu/astral/subsets/ver=2.08

# %%
# Make a list of all sids
file_path = "/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/SCOPe_data/astral-scopedom-seqres-gd-sel-gs-sc-cf-2.08.id"

# Read the file and store each value as an element in a list
with open(file_path, "r") as file:
    sid_list = [line.strip() for line in file]

pdb_list = [item[1:-2] for item in sid_list]

# %%
# Go through folder and delete all lines from folders that don't start with \"ATOM\"\n" and skip hydrogen atoms
files = sorted([f for f in os.listdir('/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/SCOPe_data/SCOPe/') if os.path.isfile(os.path.join('/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/SCOPe_data/SCOPe/',f)) and not f.startswith('.')])

for file_name in files:
    file_path = os.path.join('/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/SCOPe_data/SCOPe/', file_name)
    with open(file_path, 'r') as file:
        lines = [
            line for line in file
            if line.startswith("ATOM") and not line[12:16].strip().startswith("H")
        ]
    with open(file_path, 'w') as file:
        file.writelines(lines)

# %%
# Make list of the PED in folder pdbs and loop through this list
root = 'output/SCOPe_data/SCOPe'
list_SCOPe = []
for path, subdirs, files in os.walk(root):
    for name in files:
        if name.endswith('.pdb'):
            list_SCOPe.append(os.path.join(path, name))

list_SCOPe.sort()
list_SCOPe
# Out:
# ['output/pdbs_traj/SCOPe/.ipynb_checkpoints/16VP-checkpoint.pdb',
#  'output/pdbs_traj/SCOPe/.ipynb_checkpoints/
#  'output/pdbs_traj/SCOPe/3SXU.pdb',
#  'output/pdbs_traj/SCOPe/3T0H.pdb',
#  'output/pdbs_traj/SCOPe/3T2C.pdb',
#  'output/pdbs_traj/SCOPe/3T3L.pdb',
#  'output/pdbs_traj/SCOPe/3T6E.pdb',
#  'output/pdbs_traj/SCOPe/3T7L.pdb',
#  'output/pdbs_traj/SCOPe/3TEW.pdb',
#  'output/pdbs_traj/SCOPe/3TG0.pdb',
#  'output/pdbs_traj/SCOPe/3TG2.pdb',
#  'output/pdbs_traj/SCOPe/3TVJ.pdb',
#  'output/pdbs_traj/SCOPe/3U1L.pdb',
#  'output/pdbs_traj/SCOPe/3U9W.pdb',
#  'output/pdbs_traj/SCOPe/3UI4.pdb',
#  'output/pdbs_traj/SCOPe/3V6T.pdb',
#  'output/pdbs_traj/SCOPe/3VB9.pdb',
#  'output/pdbs_traj/SCOPe/3VDP.pdb',
#  'output/pdbs_traj/SCOPe/3VHV.pdb',
#  'output/pdbs_traj/SCOPe/3VXV.pdb',
#  'output/pdbs_traj/SCOPe/3VYP.pdb',
#  'output/pdbs_traj/SCOPe/3W5H.pdb',
#  'output/pdbs_traj/SCOPe/3WDN.pdb',
#  'output/pdbs_traj/SCOPe/3WEO.pdb',
#  'output/pdbs_traj/SCOPe/3WTS.pdb',
#  'output/pdbs_traj/SCOPe/3X0I.pdb',
#  'output/pdbs_traj/SCOPe/3X34.pdb',
#  'output/pdbs_traj/SCOPe/3ZE3.pdb',
#  'output/pdbs_traj/SCOPe/3ZIW.pdb',
#  'output/pdbs_traj/SCOPe/3ZQU.pdb',
#  'output/pdbs_traj/SCOPe/4A02.pdb',
#  'output/pdbs_traj/SCOPe/4A2V.pdb',
#  'output/pdbs_traj/SCOPe/4A8T.pdb',
#  'output/pdbs_traj/SCOPe/4A8U.pdb',
#  'output/pdbs_traj/SCOPe/4AF1.pdb',
#  'output/pdbs_traj/SCOPe/4AGH.pdb',
#  'output/pdbs_traj/SCOPe/4AL0.pdb',
#  'output/pdbs_traj/SCOPe/4AM1.pdb',
#  'output/pdbs_traj/SCOPe/4AN8.pdb',
#  'output/pdbs_traj/SCOPe/4ATM.pdb',
#  'output/pdbs_traj/SCOPe/4AXO.pdb',
#  'output/pdbs_traj/SCOPe/4B4U.pdb',
#  'output/pdbs_traj/SCOPe/4BCT.pdb',
#  'output/pdbs_traj/SCOPe/4BKH.pdb',
#  ...]

# %% [markdown]
# ## Filter on single chain and < 200 frames

# %%
exception_list = []

# Make a new folder for PED.pdb trajectories
output_dir = 'output/pdbs_traj/SCOPe_single_frame'
if not os.path.isdir(output_dir):
    os.makedirs(output_dir)

# Process each PDB trajectory file
for pdb in list_SCOPe:
    try:
        # Define the base name for saving frames
        base_name = os.path.basename(pdb)[:-4] + "_e001"

        # Check if the first frame already exists to avoid redundant processing
        if not os.path.isfile(f'{output_dir}/{base_name}.0.pdb'):
            print(f"Processing file: {base_name}")

            # Load the trajectory
            traj = mdtraj.load(pdb)

            # Check if the trajectory has less than 200 frames
            if traj.n_frames < 200:
                # Ensure it's a single-chain topology before saving frames
                if traj.topology.n_chains == 1:
                    current_segment = []
                    frame_index = 0

                    # Read the PDB content
                    with open(pdb, 'r') as file:
                        pdb_content = file.readlines()

                    # Split the PDB file into frames based on atom serial resets
                    for line in pdb_content:
                        if line.startswith("ATOM") or line.startswith("HETATM"):
                            # Extract the atom serial number
                            serial_number = int(line[6:11].strip())
                            if serial_number == 1 and current_segment:
                                # Save the completed segment to a new file
                                output_file = os.path.join(output_dir, f"{base_name}.{frame_index}.pdb")
                                with open(output_file, 'w') as frame_file:
                                    frame_file.writelines(current_segment)
                                frame_index += 1
                                current_segment = []

                        current_segment.append(line)

                    # Save the last segment if it exists
                    if current_segment:
                        output_file = os.path.join(output_dir, f"{base_name}.{frame_index}.pdb")
                        with open(output_file, 'w') as frame_file:
                            frame_file.writelines(current_segment)

                    print(f"Saved frames from {base_name} to {output_dir}")
                else:
                    print(f"Skipping {base_name}: Not a single-chain topology.")
            else:
                print(f"Skipping {base_name}: Contains {traj.n_frames} frames (exceeds limit).")
    except Exception as e:
        print(f"File {os.path.basename(pdb)} is skipped due to error: {e}")
        exception_list.append(pdb)

print("Processing completed.")
if exception_list:
    print(f"The following files were skipped due to errors: {exception_list}")
# Out:
# Processing file: 16VP-checkpoint_e001
# Skipping 16VP-checkpoint_e001: Not a single-chain topology.
# Processing file: 1AD2-checkpoint_e001
# Saved frames from 1AD2-checkpoint_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1AEP-checkpoint_e001
# Saved frames from 1AEP-checkpoint_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1AF7-checkpoint_e001
# Skipping 1AF7-checkpoint_e001: Not a single-chain topology.
# Processing file: 1B7C-checkpoint_e001
# Skipping 1B7C-checkpoint_e001: Not a single-chain topology.
# Processing file: 1BGF-checkpoint_e001
# Skipping 1BGF-checkpoint_e001: Not a single-chain topology.
# Processing file: 1F5N-checkpoint_e001
# Saved frames from 1F5N-checkpoint_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1GZS-checkpoint_e001
# Skipping 1GZS-checkpoint_e001: Not a single-chain topology.
# Processing file: 1IX9-checkpoint_e001
# Skipping 1IX9-checkpoint_e001: Not a single-chain topology.
# Processing file: 1JX4-checkpoint_e001
# Skipping 1JX4-checkpoint_e001: Not a single-chain topology.
# Processing file: 1O70-checkpoint_e001
# Saved frames from 1O70-checkpoint_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1O7J-checkpoint_e001
# Skipping 1O7J-checkpoint_e001: Not a single-chain topology.
# Processing file: 1OAI-checkpoint_e001
# Skipping 1OAI-checkpoint_e001: Not a single-chain topology.
# Processing file: 1PFV-checkpoint_e001
# Saved frames from 1PFV-checkpoint_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1PUC-checkpoint_e001
# Saved frames from 1PUC-checkpoint_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1PV5-checkpoint_e001
# Saved frames from 1PV5-checkpoint_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1Q88-checkpoint_e001
# Skipping 1Q88-checkpoint_e001: Not a single-chain topology.
# Processing file: d1b7ca_-checkpoint_e001
# File d1b7ca_-checkpoint.pdb is skipped due to error: index 0 is out of bounds for axis 0 with size 0
# Processing file: d1oaia_-checkpoint_e001
# File d1oaia_-checkpoint.pdb is skipped due to error: index 0 is out of bounds for axis 0 with size 0
# Processing file: 16VP_e001
# Saved frames from 16VP_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1A1I_e001
# Skipping 1A1I_e001: Not a single-chain topology.
# Processing file: 1A1X_e001
# Saved frames from 1A1X_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1AD2_e001
# Saved frames from 1AD2_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1AE9_e001
# Skipping 1AE9_e001: Not a single-chain topology.
# Processing file: 1AEP_e001
# Saved frames from 1AEP_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1AF7_e001
# Saved frames from 1AF7_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1AFP_e001
# Saved frames from 1AFP_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1ANS_e001
# Saved frames from 1ANS_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1AOL_e001
# Saved frames from 1AOL_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1B25_e001
# Skipping 1B25_e001: Not a single-chain topology.
# Processing file: 1B33_e001
# Skipping 1B33_e001: Not a single-chain topology.
# Processing file: 1B67_e001
# Skipping 1B67_e001: Not a single-chain topology.
# Processing file: 1B79_e001
# Skipping 1B79_e001: Not a single-chain topology.
# Processing file: 1B7C_e001
# Saved frames from 1B7C_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1BBG_e001
# Saved frames from 1BBG_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1BCO_e001
# Saved frames from 1BCO_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1BG8_e001
# Skipping 1BG8_e001: Not a single-chain topology.
# Processing file: 1BGF_e001
# Saved frames from 1BGF_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1BKR_e001
# Saved frames from 1BKR_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1BM8_e001
# Saved frames from 1BM8_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1BOU_e001
# Skipping 1BOU_e001: Not a single-chain topology.
# Processing file: 1BYI_e001
# Saved frames from 1BYI_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1C17_e001
# Skipping 1C17_e001: Not a single-chain topology.
# Processing file: 1C1K_e001
# Saved frames from 1C1K_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1CHD_e001
# Saved frames from 1CHD_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1CIP_e001
# Saved frames from 1CIP_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1CO4_e001
# Saved frames from 1CO4_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1CQ3_e001
# Skipping 1CQ3_e001: Not a single-chain topology.
# Processing file: 1CT7_e001
# Saved frames from 1CT7_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1D3Y_e001
# Skipping 1D3Y_e001: Not a single-chain topology.
# Processing file: 1D6G_e001
# Skipping 1D6G_e001: Not a single-chain topology.
# Processing file: 1DD9_e001
# Saved frames from 1DD9_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1DFU_e001
# Skipping 1DFU_e001: Not a single-chain topology.
# Processing file: 1DIV_e001
# Saved frames from 1DIV_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1DJ0_e001
# Skipping 1DJ0_e001: Not a single-chain topology.
# Processing file: 1DK8_e001
# Saved frames from 1DK8_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1DKG_e001
# Skipping 1DKG_e001: Not a single-chain topology.
# Processing file: 1DKV_e001
# Skipping 1DKV_e001: Not a single-chain topology.
# Processing file: 1DL5_e001
# Skipping 1DL5_e001: Not a single-chain topology.
# Processing file: 1DMG_e001
# Saved frames from 1DMG_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1DQC_e001
# Saved frames from 1DQC_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1DTD_e001
# Skipping 1DTD_e001: Not a single-chain topology.
# Processing file: 1DVK_e001
# Skipping 1DVK_e001: Not a single-chain topology.
# Processing file: 1DVO_e001
# Saved frames from 1DVO_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1DZF_e001
# Saved frames from 1DZF_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1E19_e001
# Skipping 1E19_e001: Not a single-chain topology.
# Processing file: 1E44_e001
# Skipping 1E44_e001: Not a single-chain topology.
# Processing file: 1E8P_e001
# Saved frames from 1E8P_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1EB6_e001
# Saved frames from 1EB6_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1ECI_e001
# Skipping 1ECI_e001: Not a single-chain topology.
# Processing file: 1ECW_e001
# Saved frames from 1ECW_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1EGW_e001
# Skipping 1EGW_e001: Not a single-chain topology.
# Processing file: 1EJ5_e001
# Saved frames from 1EJ5_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1EL6_e001
# Skipping 1EL6_e001: Not a single-chain topology.
# Processing file: 1EM8_e001
# Skipping 1EM8_e001: Not a single-chain topology.
# Processing file: 1EU1_e001
# Saved frames from 1EU1_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1EWF_e001
# Saved frames from 1EWF_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1EYF_e001
# Saved frames from 1EYF_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1F0A_e001
# Saved frames from 1F0A_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1F32_e001
# Saved frames from 1F32_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1F35_e001
# Skipping 1F35_e001: Not a single-chain topology.
# Processing file: 1F3U_e001
# Skipping 1F3U_e001: Not a single-chain topology.
# Processing file: 1F5N_e001
# Saved frames from 1F5N_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1F6V_e001
# Saved frames from 1F6V_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1F86_e001
# Skipping 1F86_e001: Not a single-chain topology.
# Processing file: 1F9Y_e001
# Saved frames from 1F9Y_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1FJG_e001
# Skipping 1FJG_e001: Not a single-chain topology.
# Processing file: 1FJR_e001
# Skipping 1FJR_e001: Not a single-chain topology.
# Processing file: 1FK5_e001
# Saved frames from 1FK5_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1FN9_e001
# Skipping 1FN9_e001: Not a single-chain topology.
# Processing file: 1FS1_e001
# Skipping 1FS1_e001: Not a single-chain topology.
# Processing file: 1FSG_e001
# Skipping 1FSG_e001: Not a single-chain topology.
# Processing file: 1G2R_e001
# Saved frames from 1G2R_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1G2Y_e001
# Skipping 1G2Y_e001: Not a single-chain topology.
# Processing file: 1G3P_e001
# Saved frames from 1G3P_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1G4I_e001
# Saved frames from 1G4I_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1G5G_e001
# Skipping 1G5G_e001: Not a single-chain topology.
# Processing file: 1G6X_e001
# Saved frames from 1G6X_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1G7S_e001
# Saved frames from 1G7S_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1G8E_e001
# Skipping 1G8E_e001: Not a single-chain topology.
# Processing file: 1GCI_e001
# Saved frames from 1GCI_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1GD8_e001
# Skipping 1GD8_e001: Not a single-chain topology.
# Processing file: 1GK9_e001
# Skipping 1GK9_e001: Not a single-chain topology.
# Processing file: 1GKM_e001
# Saved frames from 1GKM_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1GMU_e001
# Skipping 1GMU_e001: Not a single-chain topology.
# Processing file: 1GMX_e001
# Saved frames from 1GMX_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1GPJ_e001
# Saved frames from 1GPJ_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1GQE_e001
# Saved frames from 1GQE_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1GWE_e001
# Saved frames from 1GWE_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1GZS_e001
# Skipping 1GZS_e001: Not a single-chain topology.
# Processing file: 1H03_e001
# Skipping 1H03_e001: Not a single-chain topology.
# Processing file: 1H4X_e001
# Skipping 1H4X_e001: Not a single-chain topology.
# Processing file: 1H5W_e001
# Skipping 1H5W_e001: Not a single-chain topology.
# Processing file: 1H99_e001
# Saved frames from 1H99_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1HA8_e001
# Saved frames from 1HA8_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1HF2_e001
# Skipping 1HF2_e001: Not a single-chain topology.
# Processing file: 1HI9_e001
# Skipping 1HI9_e001: Not a single-chain topology.
# Processing file: 1HP1_e001
# Saved frames from 1HP1_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1HQ1_e001
# Skipping 1HQ1_e001: Not a single-chain topology.
# Processing file: 1HUF_e001
# Saved frames from 1HUF_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1HW1_e001
# Skipping 1HW1_e001: Not a single-chain topology.
# Processing file: 1HXN_e001
# Saved frames from 1HXN_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1HYO_e001
# Skipping 1HYO_e001: Not a single-chain topology.
# Processing file: 1I2T_e001
# Saved frames from 1I2T_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1I3J_e001
# Skipping 1I3J_e001: Not a single-chain topology.
# Processing file: 1I4J_e001
# Skipping 1I4J_e001: Not a single-chain topology.
# Processing file: 1IG3_e001
# Skipping 1IG3_e001: Not a single-chain topology.
# Processing file: 1IIE_e001
# Skipping 1IIE_e001: Not a single-chain topology.
# Processing file: 1IJY_e001
# Skipping 1IJY_e001: Not a single-chain topology.
# Processing file: 1IO1_e001
# Saved frames from 1IO1_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1IQO_e001
# Saved frames from 1IQO_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1IRQ_e001
# Skipping 1IRQ_e001: Not a single-chain topology.
# Processing file: 1IS9_e001
# Saved frames from 1IS9_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1IUQ_e001
# Saved frames from 1IUQ_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1IWG_e001
# Saved frames from 1IWG_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1IX9_e001
# Skipping 1IX9_e001: Not a single-chain topology.
# Processing file: 1IXM_e001
# Skipping 1IXM_e001: Not a single-chain topology.
# Processing file: 1IYJ_e001
# Skipping 1IYJ_e001: Not a single-chain topology.
# Processing file: 1IYR_e001
# Saved frames from 1IYR_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1IZM_e001
# Saved frames from 1IZM_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1J09_e001
# Saved frames from 1J09_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1J0T_e001
# Saved frames from 1J0T_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1J2M_e001
# Saved frames from 1J2M_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1J3A_e001
# Saved frames from 1J3A_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1J5U_e001
# Saved frames from 1J5U_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1J8U_e001
# Saved frames from 1J8U_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1J98_e001
# Saved frames from 1J98_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1JB0_e001
# Skipping 1JB0_e001: Not a single-chain topology.
# Processing file: 1JBI_e001
# Saved frames from 1JBI_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1JFB_e001
# Saved frames from 1JFB_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1JG1_e001
# Saved frames from 1JG1_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1JID_e001
# Skipping 1JID_e001: Not a single-chain topology.
# Processing file: 1JJC_e001
# Skipping 1JJC_e001: Not a single-chain topology.
# Processing file: 1JKE_e001
# Skipping 1JKE_e001: Not a single-chain topology.
# Processing file: 1JM1_e001
# Saved frames from 1JM1_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1JMU_e001
# Skipping 1JMU_e001: Not a single-chain topology.
# Processing file: 1JS8_e001
# Skipping 1JS8_e001: Not a single-chain topology.
# Processing file: 1JV2_e001
# Skipping 1JV2_e001: Not a single-chain topology.
# Processing file: 1JW9_e001
# Skipping 1JW9_e001: Not a single-chain topology.
# Processing file: 1JX4_e001
# Skipping 1JX4_e001: Not a single-chain topology.
# Processing file: 1K0R_e001
# Skipping 1K0R_e001: Not a single-chain topology.
# Processing file: 1K18_e001
# Saved frames from 1K18_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1K1F_e001
# Skipping 1K1F_e001: Not a single-chain topology.
# Processing file: 1K20_e001
# Skipping 1K20_e001: Not a single-chain topology.
# Processing file: 1K2A_e001
# Saved frames from 1K2A_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1K2Y_e001
# Saved frames from 1K2Y_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1K3X_e001
# Skipping 1K3X_e001: Not a single-chain topology.
# Processing file: 1K4I_e001
# Saved frames from 1K4I_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1K5C_e001
# Saved frames from 1K5C_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1K5N_e001
# Skipping 1K5N_e001: Not a single-chain topology.
# Processing file: 1K6K_e001
# Saved frames from 1K6K_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1K8K_e001
# Skipping 1K8K_e001: Not a single-chain topology.
# Processing file: 1K8T_e001
# Saved frames from 1K8T_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1K91_e001
# Saved frames from 1K91_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1K92_e001
# Saved frames from 1K92_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1KA1_e001
# Saved frames from 1KA1_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1KAF_e001
# Skipping 1KAF_e001: Not a single-chain topology.
# Processing file: 1KB0_e001
# Saved frames from 1KB0_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1KG1_e001
# Saved frames from 1KG1_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1KJN_e001
# Skipping 1KJN_e001: Not a single-chain topology.
# Processing file: 1KJQ_e001
# Skipping 1KJQ_e001: Not a single-chain topology.
# Processing file: 1KNL_e001
# Saved frames from 1KNL_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1KNZ_e001
# Skipping 1KNZ_e001: Not a single-chain topology.
# Processing file: 1KO6_e001
# Skipping 1KO6_e001: Not a single-chain topology.
# Processing file: 1KPT_e001
# Skipping 1KPT_e001: Not a single-chain topology.
# Processing file: 1KQ6_e001
# Saved frames from 1KQ6_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1KQF_e001
# Skipping 1KQF_e001: Not a single-chain topology.
# Processing file: 1KQP_e001
# Skipping 1KQP_e001: Not a single-chain topology.
# Processing file: 1L1L_e001
# Skipping 1L1L_e001: Not a single-chain topology.
# Processing file: 1L7U_e001
# Saved frames from 1L7U_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1L8W_e001
# Skipping 1L8W_e001: Not a single-chain topology.
# Processing file: 1L9L_e001
# Saved frames from 1L9L_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1LC0_e001
# Saved frames from 1LC0_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1LDJ_e001
# Skipping 1LDJ_e001: Not a single-chain topology.
# Processing file: 1LFP_e001
# Saved frames from 1LFP_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1LG7_e001
# Saved frames from 1LG7_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1LKK_e001
# Skipping 1LKK_e001: Not a single-chain topology.
# Processing file: 1LKT_e001
# Skipping 1LKT_e001: Not a single-chain topology.
# Processing file: 1LLA_e001
# Saved frames from 1LLA_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1LPV_e001
# Saved frames from 1LPV_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1LQU_e001
# Skipping 1LQU_e001: Not a single-chain topology.
# Processing file: 1LSH_e001
# Skipping 1LSH_e001: Not a single-chain topology.
# Processing file: 1LSL_e001
# Saved frames from 1LSL_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1M1C_e001
# Skipping 1M1C_e001: Not a single-chain topology.
# Processing file: 1M1E_e001
# Skipping 1M1E_e001: Not a single-chain topology.
# Processing file: 1M1H_e001
# Saved frames from 1M1H_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1M55_e001
# Skipping 1M55_e001: Not a single-chain topology.
# Processing file: 1MF7_e001
# Saved frames from 1MF7_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1MIW_e001
# Skipping 1MIW_e001: Not a single-chain topology.
# Processing file: 1MK0_e001
# Saved frames from 1MK0_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1MKC_e001
# Saved frames from 1MKC_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1MKF_e001
# Skipping 1MKF_e001: Not a single-chain topology.
# Processing file: 1MLA_e001
# Saved frames from 1MLA_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1MP1_e001
# Saved frames from 1MP1_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1MSO_e001
# Skipping 1MSO_e001: Not a single-chain topology.
# Processing file: 1MUN_e001
# Saved frames from 1MUN_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1MVF_e001
# Skipping 1MVF_e001: Not a single-chain topology.
# Processing file: 1MW5_e001
# Skipping 1MW5_e001: Not a single-chain topology.
# Processing file: 1MW9_e001
# Saved frames from 1MW9_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1N13_e001
# Skipping 1N13_e001: Not a single-chain topology.
# Processing file: 1N4W_e001
# Saved frames from 1N4W_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1N62_e001
# Skipping 1N62_e001: Not a single-chain topology.
# Processing file: 1N6Z_e001
# Saved frames from 1N6Z_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1N7V_e001
# Saved frames from 1N7V_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1N7Z_e001
# Skipping 1N7Z_e001: Not a single-chain topology.
# Processing file: 1N81_e001
# Saved frames from 1N81_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1N91_e001
# Saved frames from 1N91_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1N93_e001
# Saved frames from 1N93_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1NA6_e001
# Skipping 1NA6_e001: Not a single-chain topology.
# Processing file: 1NC7_e001
# Skipping 1NC7_e001: Not a single-chain topology.
# Processing file: 1NEI_e001
# Skipping 1NEI_e001: Not a single-chain topology.
# Processing file: 1NG6_e001
# Saved frames from 1NG6_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1NG7_e001
# Skipping 1NG7_e001: Not a single-chain topology.
# Processing file: 1NH1_e001
# Saved frames from 1NH1_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1NH2_e001
# Skipping 1NH2_e001: Not a single-chain topology.
# Processing file: 1NJ7_e001
# Saved frames from 1NJ7_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1NJH_e001
# Saved frames from 1NJH_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1NKD_e001
# Saved frames from 1NKD_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1NKI_e001
# Skipping 1NKI_e001: Not a single-chain topology.
# Processing file: 1NKZ_e001
# Skipping 1NKZ_e001: Not a single-chain topology.
# Processing file: 1NLS_e001
# Saved frames from 1NLS_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1NLT_e001
# Skipping 1NLT_e001: Not a single-chain topology.
# Processing file: 1NO1_e001
# Skipping 1NO1_e001: Not a single-chain topology.
# Processing file: 1NO7_e001
# Skipping 1NO7_e001: Not a single-chain topology.
# Processing file: 1NQU_e001
# Skipping 1NQU_e001: Not a single-chain topology.
# Processing file: 1NR3_e001
# Saved frames from 1NR3_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1NTY_e001
# Saved frames from 1NTY_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1NWZ_e001
# Saved frames from 1NWZ_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1NXH_e001
# Skipping 1NXH_e001: Not a single-chain topology.
# Processing file: 1NY9_e001
# Saved frames from 1NY9_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1NZI_e001
# Skipping 1NZI_e001: Not a single-chain topology.
# Processing file: 1O22_e001
# Saved frames from 1O22_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1O5H_e001
# Skipping 1O5H_e001: Not a single-chain topology.
# Processing file: 1O5Y_e001
# Skipping 1O5Y_e001: Not a single-chain topology.
# Processing file: 1O6A_e001
# Skipping 1O6A_e001: Not a single-chain topology.
# Processing file: 1O70_e001
# Saved frames from 1O70_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1O75_e001
# Skipping 1O75_e001: Not a single-chain topology.
# Processing file: 1O7J_e001
# Skipping 1O7J_e001: Not a single-chain topology.
# Processing file: 1O8B_e001
# Skipping 1O8B_e001: Not a single-chain topology.
# Processing file: 1O8R_e001
# Saved frames from 1O8R_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1O98_e001
# Saved frames from 1O98_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1OAI_e001
# Skipping 1OAI_e001: Not a single-chain topology.
# Processing file: 1OC0_e001
# Skipping 1OC0_e001: Not a single-chain topology.
# Processing file: 1OCY_e001
# Saved frames from 1OCY_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1ODH_e001
# Skipping 1ODH_e001: Not a single-chain topology.
# Processing file: 1OED_e001
# Skipping 1OED_e001: Not a single-chain topology.
# Processing file: 1OFC_e001
# Saved frames from 1OFC_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1OGM_e001
# Saved frames from 1OGM_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1OH0_e001
# Skipping 1OH0_e001: Not a single-chain topology.
# Processing file: 1OIS_e001
# Saved frames from 1OIS_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1OJH_e001
# Skipping 1OJH_e001: Not a single-chain topology.
# Processing file: 1OK0_e001
# Saved frames from 1OK0_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1OKC_e001
# Saved frames from 1OKC_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1ON2_e001
# Skipping 1ON2_e001: Not a single-chain topology.
# Processing file: 1OO0_e001
# Skipping 1OO0_e001: Not a single-chain topology.
# Processing file: 1OQJ_e001
# Skipping 1OQJ_e001: Not a single-chain topology.
# Processing file: 1OR7_e001
# Skipping 1OR7_e001: Not a single-chain topology.
# Processing file: 1ORD_e001
# Skipping 1ORD_e001: Not a single-chain topology.
# Processing file: 1ORU_e001
# Skipping 1ORU_e001: Not a single-chain topology.
# Processing file: 1OU8_e001
# Skipping 1OU8_e001: Not a single-chain topology.
# Processing file: 1OV9_e001
# Skipping 1OV9_e001: Not a single-chain topology.
# Processing file: 1OW1_e001
# Saved frames from 1OW1_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1OWL_e001
# Saved frames from 1OWL_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1P0Y_e001
# Skipping 1P0Y_e001: Not a single-chain topology.
# Processing file: 1P35_e001
# Skipping 1P35_e001: Not a single-chain topology.
# Processing file: 1P3D_e001
# Skipping 1P3D_e001: Not a single-chain topology.
# Processing file: 1P6O_e001
# Skipping 1P6O_e001: Not a single-chain topology.
# Processing file: 1P9Y_e001
# Skipping 1P9Y_e001: Not a single-chain topology.
# Processing file: 1PB5_e001
# Saved frames from 1PB5_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1PC6_e001
# Skipping 1PC6_e001: Not a single-chain topology.
# Processing file: 1PFO_e001
# Saved frames from 1PFO_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1PFV_e001
# Saved frames from 1PFV_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1PM4_e001
# Skipping 1PM4_e001: Not a single-chain topology.
# Processing file: 1PN1_e001
# Skipping 1PN1_e001: Not a single-chain topology.
# Processing file: 1PP0_e001
# Skipping 1PP0_e001: Not a single-chain topology.
# Processing file: 1PPR_e001
# Skipping 1PPR_e001: Not a single-chain topology.
# Processing file: 1PU1_e001
# Saved frames from 1PU1_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1PUC_e001
# Saved frames from 1PUC_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1PV5_e001
# Saved frames from 1PV5_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1PX5_e001
# Skipping 1PX5_e001: Not a single-chain topology.
# Processing file: 1PXE_e001
# Saved frames from 1PXE_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1PYY_e001
# Saved frames from 1PYY_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1PZ4_e001
# Saved frames from 1PZ4_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1Q3Q_e001
# Skipping 1Q3Q_e001: Not a single-chain topology.
# Processing file: 1Q5Z_e001
# Saved frames from 1Q5Z_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1Q88_e001
# Skipping 1Q88_e001: Not a single-chain topology.
# Processing file: 1Q8D_e001
# Saved frames from 1Q8D_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1QEX_e001
# Skipping 1QEX_e001: Not a single-chain topology.
# Processing file: 1QHD_e001
# Saved frames from 1QHD_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1QTN_e001
# Skipping 1QTN_e001: Not a single-chain topology.
# Processing file: 1QTS_e001
# Saved frames from 1QTS_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1QW2_e001
# Saved frames from 1QW2_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1QWZ_e001
# Saved frames from 1QWZ_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1R0D_e001
# Skipping 1R0D_e001: Not a single-chain topology.
# Processing file: 1R0R_e001
# Skipping 1R0R_e001: Not a single-chain topology.
# Processing file: 1R0V_e001
# Skipping 1R0V_e001: Not a single-chain topology.
# Processing file: 1R29_e001
# Saved frames from 1R29_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1R5S_e001
# Saved frames from 1R5S_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1R6J_e001
# Saved frames from 1R6J_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1R75_e001
# Saved frames from 1R75_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1R7L_e001
# Skipping 1R7L_e001: Not a single-chain topology.
# Processing file: 1R9F_e001
# Skipping 1R9F_e001: Not a single-chain topology.
# Processing file: 1RA0_e001
# Saved frames from 1RA0_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1RCQ_e001
# Saved frames from 1RCQ_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1RF8_e001
# Skipping 1RF8_e001: Not a single-chain topology.
# Processing file: 1RH1_e001
# Saved frames from 1RH1_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1RJU_e001
# Saved frames from 1RJU_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1RKI_e001
# Skipping 1RKI_e001: Not a single-chain topology.
# Processing file: 1RO2_e001
# Saved frames from 1RO2_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1RSS_e001
# Saved frames from 1RSS_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1RTQ_e001
# Saved frames from 1RTQ_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1RWA_e001
# Saved frames from 1RWA_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1RYL_e001
# Skipping 1RYL_e001: Not a single-chain topology.
# Processing file: 1S7M_e001
# Skipping 1S7M_e001: Not a single-chain topology.
# Processing file: 1S7Z_e001
# Saved frames from 1S7Z_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1SAU_e001
# Saved frames from 1SAU_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1SBX_e001
# Saved frames from 1SBX_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1SDI_e001
# Saved frames from 1SDI_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1SED_e001
# Skipping 1SED_e001: Not a single-chain topology.
# Processing file: 1SEI_e001
# Skipping 1SEI_e001: Not a single-chain topology.
# Processing file: 1SF8_e001
# Skipping 1SF8_e001: Not a single-chain topology.
# Processing file: 1SG2_e001
# Skipping 1SG2_e001: Not a single-chain topology.
# Processing file: 1SG4_e001
# Skipping 1SG4_e001: Not a single-chain topology.
# Processing file: 1SG7_e001
# Saved frames from 1SG7_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1SJ7_e001
# Skipping 1SJ7_e001: Not a single-chain topology.
# Processing file: 1SKN_e001
# Skipping 1SKN_e001: Not a single-chain topology.
# Processing file: 1SLQ_e001
# Skipping 1SLQ_e001: Not a single-chain topology.
# Processing file: 1SLU_e001
# Skipping 1SLU_e001: Not a single-chain topology.
# Processing file: 1SMB_e001
# Saved frames from 1SMB_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1SO9_e001
# Saved frames from 1SO9_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1SOP_e001
# Saved frames from 1SOP_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1SR8_e001
# Saved frames from 1SR8_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1SR9_e001
# Skipping 1SR9_e001: Not a single-chain topology.
# Processing file: 1SRQ_e001
# Skipping 1SRQ_e001: Not a single-chain topology.
# Processing file: 1SS6_e001
# Saved frames from 1SS6_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1SSE_e001
# Skipping 1SSE_e001: Not a single-chain topology.
# Processing file: 1SYX_e001
# Skipping 1SYX_e001: Not a single-chain topology.
# Processing file: 1SZ7_e001
# Saved frames from 1SZ7_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1SZH_e001
# Skipping 1SZH_e001: Not a single-chain topology.
# Processing file: 1T07_e001
# Saved frames from 1T07_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1T15_e001
# Skipping 1T15_e001: Not a single-chain topology.
# Processing file: 1T1U_e001
# Saved frames from 1T1U_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1T2D_e001
# Saved frames from 1T2D_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1T36_e001
# Skipping 1T36_e001: Not a single-chain topology.
# Processing file: 1T77_e001
# Skipping 1T77_e001: Not a single-chain topology.
# Processing file: 1T95_e001
# Saved frames from 1T95_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1TBA_e001
# Skipping 1TBA_e001: Not a single-chain topology.
# Processing file: 1TBF_e001
# Saved frames from 1TBF_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1TD6_e001
# Saved frames from 1TD6_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1TF5_e001
# Saved frames from 1TF5_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1TFE_e001
# Saved frames from 1TFE_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1TJ2_e001
# Saved frames from 1TJ2_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1TJX_e001
# Saved frames from 1TJX_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1TKE_e001
# Saved frames from 1TKE_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1TLH_e001
# Skipping 1TLH_e001: Not a single-chain topology.
# Processing file: 1TLJ_e001
# Skipping 1TLJ_e001: Not a single-chain topology.
# Processing file: 1TM9_e001
# Saved frames from 1TM9_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1TS9_e001
# Saved frames from 1TS9_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1TT8_e001
# Saved frames from 1TT8_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1TWF_e001
# Skipping 1TWF_e001: Not a single-chain topology.
# Processing file: 1TX4_e001
# Skipping 1TX4_e001: Not a single-chain topology.
# Processing file: 1TX9_e001
# Skipping 1TX9_e001: Not a single-chain topology.
# Processing file: 1TZP_e001
# Skipping 1TZP_e001: Not a single-chain topology.
# Processing file: 1TZV_e001
# Saved frames from 1TZV_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1U07_e001
# Skipping 1U07_e001: Not a single-chain topology.
# Processing file: 1U5K_e001
# Skipping 1U5K_e001: Not a single-chain topology.
# Processing file: 1U61_e001
# Saved frames from 1U61_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1U6K_e001
# Skipping 1U6K_e001: Not a single-chain topology.
# Processing file: 1U7L_e001
# Saved frames from 1U7L_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1U84_e001
# Saved frames from 1U84_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1U94_e001
# Saved frames from 1U94_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1UCD_e001
# Saved frames from 1UCD_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1UCS_e001
# Saved frames from 1UCS_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1UD9_e001
# Skipping 1UD9_e001: Not a single-chain topology.
# Processing file: 1UDX_e001
# Saved frames from 1UDX_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1UFY_e001
# Saved frames from 1UFY_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1UM0_e001
# Skipping 1UM0_e001: Not a single-chain topology.
# Processing file: 1UPT_e001
# Skipping 1UPT_e001: Not a single-chain topology.
# Processing file: 1URJ_e001
# Skipping 1URJ_e001: Not a single-chain topology.
# Processing file: 1US0_e001
# Saved frames from 1US0_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1US7_e001
# Skipping 1US7_e001: Not a single-chain topology.
# Processing file: 1USM_e001
# Saved frames from 1USM_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1UT7_e001
# Skipping 1UT7_e001: Not a single-chain topology.
# Processing file: 1UTG_e001
# Saved frames from 1UTG_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1UTY_e001
# Skipping 1UTY_e001: Not a single-chain topology.
# Processing file: 1UUJ_e001
# Skipping 1UUJ_e001: Not a single-chain topology.
# Processing file: 1UUY_e001
# Saved frames from 1UUY_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1UWK_e001
# Skipping 1UWK_e001: Not a single-chain topology.
# Processing file: 1UX6_e001
# Saved frames from 1UX6_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1UXY_e001
# Saved frames from 1UXY_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1UZ3_e001
# Skipping 1UZ3_e001: Not a single-chain topology.
# Processing file: 1UZK_e001
# Saved frames from 1UZK_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1V0W_e001
# Saved frames from 1V0W_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1V2Z_e001
# Saved frames from 1V2Z_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1V30_e001
# Saved frames from 1V30_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1V37_e001
# Skipping 1V37_e001: Not a single-chain topology.
# Processing file: 1V65_e001
# Saved frames from 1V65_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1V6P_e001
# Skipping 1V6P_e001: Not a single-chain topology.
# Processing file: 1V7Z_e001
# Skipping 1V7Z_e001: Not a single-chain topology.
# Processing file: 1V9D_e001
# Skipping 1V9D_e001: Not a single-chain topology.
# Processing file: 1V9M_e001
# Saved frames from 1V9M_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1VAJ_e001
# Saved frames from 1VAJ_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1VBW_e001
# Saved frames from 1VBW_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1VCC_e001
# Saved frames from 1VCC_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1VF6_e001
# Skipping 1VF6_e001: Not a single-chain topology.
# Processing file: 1VF7_e001
# Skipping 1VF7_e001: Not a single-chain topology.
# Processing file: 1VFI_e001
# Saved frames from 1VFI_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1VIO_e001
# Skipping 1VIO_e001: Not a single-chain topology.
# Processing file: 1VJF_e001
# Saved frames from 1VJF_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1VK1_e001
# Saved frames from 1VK1_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1VKE_e001
# Skipping 1VKE_e001: Not a single-chain topology.
# Processing file: 1VKM_e001
# Skipping 1VKM_e001: Not a single-chain topology.
# Processing file: 1VKY_e001
# Skipping 1VKY_e001: Not a single-chain topology.
# Processing file: 1VLR_e001
# Skipping 1VLR_e001: Not a single-chain topology.
# Processing file: 1VLY_e001
# Saved frames from 1VLY_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1VMH_e001
# Saved frames from 1VMH_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1VNS_e001
# Saved frames from 1VNS_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1VP8_e001
# Saved frames from 1VP8_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1VQ0_e001
# Skipping 1VQ0_e001: Not a single-chain topology.
# Processing file: 1VQ8_e001
# Skipping 1VQ8_e001: Not a single-chain topology.
# Processing file: 1VR0_e001
# Skipping 1VR0_e001: Not a single-chain topology.
# Processing file: 1VR7_e001
# Skipping 1VR7_e001: Not a single-chain topology.
# Processing file: 1VR8_e001
# Saved frames from 1VR8_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1VYI_e001
# Saved frames from 1VYI_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1VYY_e001
# Saved frames from 1VYY_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1W0N_e001
# Saved frames from 1W0N_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1W26_e001
# Skipping 1W26_e001: Not a single-chain topology.
# Processing file: 1W66_e001
# Saved frames from 1W66_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1WB9_e001
# Skipping 1WB9_e001: Not a single-chain topology.
# Processing file: 1WCW_e001
# Saved frames from 1WCW_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1WDD_e001
# Skipping 1WDD_e001: Not a single-chain topology.
# Processing file: 1WFE_e001
# Saved frames from 1WFE_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1WHI_e001
# Saved frames from 1WHI_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1WJ0_e001
# Saved frames from 1WJ0_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1WJX_e001
# Saved frames from 1WJX_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1WLG_e001
# Skipping 1WLG_e001: Not a single-chain topology.
# Processing file: 1WN2_e001
# Saved frames from 1WN2_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1WNA_e001
# Saved frames from 1WNA_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1WNY_e001
# Skipping 1WNY_e001: Not a single-chain topology.
# Processing file: 1WPB_e001
# Skipping 1WPB_e001: Not a single-chain topology.
# Processing file: 1WRV_e001
# Skipping 1WRV_e001: Not a single-chain topology.
# Processing file: 1WTJ_e001
# Skipping 1WTJ_e001: Not a single-chain topology.
# Processing file: 1WVK_e001
# Saved frames from 1WVK_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1WVQ_e001
# Skipping 1WVQ_e001: Not a single-chain topology.
# Processing file: 1WY5_e001
# Skipping 1WY5_e001: Not a single-chain topology.
# Processing file: 1X0G_e001
# Skipping 1X0G_e001: Not a single-chain topology.
# Processing file: 1X3L_e001
# Saved frames from 1X3L_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1X6I_e001
# Skipping 1X6I_e001: Not a single-chain topology.
# Processing file: 1X6Z_e001
# Saved frames from 1X6Z_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1X9N_e001
# Skipping 1X9N_e001: Not a single-chain topology.
# Processing file: 1X9Z_e001
# Skipping 1X9Z_e001: Not a single-chain topology.
# Processing file: 1XEO_e001
# Saved frames from 1XEO_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1XG0_e001
# Skipping 1XG0_e001: Not a single-chain topology.
# Processing file: 1XKP_e001
# Skipping 1XKP_e001: Not a single-chain topology.
# Processing file: 1XKR_e001
# Saved frames from 1XKR_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1XLY_e001
# Skipping 1XLY_e001: Not a single-chain topology.
# Processing file: 1XN8_e001
# Saved frames from 1XN8_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1XOU_e001
# Skipping 1XOU_e001: Not a single-chain topology.
# Processing file: 1XQB_e001
# Skipping 1XQB_e001: Not a single-chain topology.
# Processing file: 1XTA_e001
# Skipping 1XTA_e001: Not a single-chain topology.
# Processing file: 1XU1_e001
# Skipping 1XU1_e001: Not a single-chain topology.
# Processing file: 1XUB_e001
# Saved frames from 1XUB_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1Y0N_e001
# Saved frames from 1Y0N_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1Y0P_e001
# Saved frames from 1Y0P_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1Y6X_e001
# Saved frames from 1Y6X_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1Y9I_e001
# Skipping 1Y9I_e001: Not a single-chain topology.
# Processing file: 1YB3_e001
# Saved frames from 1YB3_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1YDU_e001
# Saved frames from 1YDU_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1YFS_e001
# Skipping 1YFS_e001: Not a single-chain topology.
# Processing file: 1YIB_e001
# Saved frames from 1YIB_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1YKH_e001
# Skipping 1YKH_e001: Not a single-chain topology.
# Processing file: 1YOZ_e001
# Skipping 1YOZ_e001: Not a single-chain topology.
# Processing file: 1YU0_e001
# Saved frames from 1YU0_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1YU5_e001
# Saved frames from 1YU5_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1Z0S_e001
# Skipping 1Z0S_e001: Not a single-chain topology.
# Processing file: 1Z0W_e001
# Saved frames from 1Z0W_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1Z1A_e001
# Skipping 1Z1A_e001: Not a single-chain topology.
# Processing file: 1Z21_e001
# Saved frames from 1Z21_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1Z2U_e001
# Saved frames from 1Z2U_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1Z3X_e001
# Saved frames from 1Z3X_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1Z67_e001
# Saved frames from 1Z67_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1Z8G_e001
# Skipping 1Z8G_e001: Not a single-chain topology.
# Processing file: 1ZAT_e001
# Saved frames from 1ZAT_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1ZAV_e001
# Skipping 1ZAV_e001: Not a single-chain topology.
# Processing file: 1ZBP_e001
# Saved frames from 1ZBP_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1ZD0_e001
# Saved frames from 1ZD0_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1ZDY_e001
# Saved frames from 1ZDY_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1ZE3_e001
# Skipping 1ZE3_e001: Not a single-chain topology.
# Processing file: 1ZEL_e001
# Skipping 1ZEL_e001: Not a single-chain topology.
# Processing file: 1ZHX_e001
# Saved frames from 1ZHX_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1ZJC_e001
# Saved frames from 1ZJC_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1ZL0_e001
# Skipping 1ZL0_e001: Not a single-chain topology.
# Processing file: 1ZME_e001
# Skipping 1ZME_e001: Not a single-chain topology.
# Processing file: 1ZN6_e001
# Saved frames from 1ZN6_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1ZPS_e001
# Skipping 1ZPS_e001: Not a single-chain topology.
# Processing file: 1ZRO_e001
# Skipping 1ZRO_e001: Not a single-chain topology.
# Processing file: 1ZT2_e001
# Skipping 1ZT2_e001: Not a single-chain topology.
# Processing file: 1ZT5_e001
# Saved frames from 1ZT5_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 1ZZK_e001
# Saved frames from 1ZZK_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2A73_e001
# Skipping 2A73_e001: Not a single-chain topology.
# Processing file: 2A90_e001
# Saved frames from 2A90_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2A9D_e001
# Skipping 2A9D_e001: Not a single-chain topology.
# Processing file: 2ABS_e001
# Saved frames from 2ABS_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2AD6_e001
# Skipping 2AD6_e001: Not a single-chain topology.
# Processing file: 2AEF_e001
# Skipping 2AEF_e001: Not a single-chain topology.
# Processing file: 2AG4_e001
# Skipping 2AG4_e001: Not a single-chain topology.
# Processing file: 2AGY_e001
# Skipping 2AGY_e001: Not a single-chain topology.
# Processing file: 2AIB_e001
# Skipping 2AIB_e001: Not a single-chain topology.
# Processing file: 2AJ7_e001
# Skipping 2AJ7_e001: Not a single-chain topology.
# Processing file: 2APL_e001
# Saved frames from 2APL_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2ASK_e001
# Skipping 2ASK_e001: Not a single-chain topology.
# Processing file: 2AU5_e001
# Saved frames from 2AU5_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2AUW_e001
# Skipping 2AUW_e001: Not a single-chain topology.
# Processing file: 2AVU_e001
# Skipping 2AVU_e001: Not a single-chain topology.
# Processing file: 2AXW_e001
# Skipping 2AXW_e001: Not a single-chain topology.
# Processing file: 2AYD_e001
# Saved frames from 2AYD_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2AZE_e001
# Skipping 2AZE_e001: Not a single-chain topology.
# Processing file: 2B1Y_e001
# Saved frames from 2B1Y_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2B2H_e001
# Saved frames from 2B2H_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2B2M_e001
# Saved frames from 2B2M_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2B3W_e001
# Saved frames from 2B3W_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2B3Y_e001
# Skipping 2B3Y_e001: Not a single-chain topology.
# Processing file: 2B5L_e001
# Skipping 2B5L_e001: Not a single-chain topology.
# Processing file: 2B97_e001
# Skipping 2B97_e001: Not a single-chain topology.
# Processing file: 2B9D_e001
# Skipping 2B9D_e001: Not a single-chain topology.
# Processing file: 2BAI_e001
# Saved frames from 2BAI_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2BAY_e001
# Skipping 2BAY_e001: Not a single-chain topology.
# Processing file: 2BBH_e001
# Saved frames from 2BBH_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2BJQ_e001
# Saved frames from 2BJQ_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2BLN_e001
# Skipping 2BLN_e001: Not a single-chain topology.
# Processing file: 2BNK_e001
# Skipping 2BNK_e001: Not a single-chain topology.
# Processing file: 2BOG_e001
# Saved frames from 2BOG_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2BRF_e001
# Saved frames from 2BRF_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2BTI_e001
# Skipping 2BTI_e001: Not a single-chain topology.
# Processing file: 2BTV_e001
# Skipping 2BTV_e001: Not a single-chain topology.
# Processing file: 2BW3_e001
# Skipping 2BW3_e001: Not a single-chain topology.
# Processing file: 2BZ1_e001
# Saved frames from 2BZ1_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2BZV_e001
# Saved frames from 2BZV_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 2C0G_e001
# ...
# Processing file: 4G78_e001
# Saved frames from 4G78_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4GH0_e001
# Saved frames from 4GH0_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4GMU_e001
# Saved frames from 4GMU_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4GQ4_e001
# Saved frames from 4GQ4_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4GT9_e001
# Saved frames from 4GT9_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4GV2_e001
# Saved frames from 4GV2_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4GVQ_e001
# Skipping 4GVQ_e001: Not a single-chain topology.
# Processing file: 4H27_e001
# Saved frames from 4H27_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4H8E_e001
# Saved frames from 4H8E_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4HDR_e001
# Skipping 4HDR_e001: Not a single-chain topology.
# Processing file: 4HLS_e001
# Skipping 4HLS_e001: Not a single-chain topology.
# Processing file: 4HS1_e001
# Saved frames from 4HS1_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4HTG_e001
# Saved frames from 4HTG_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4I6Y_e001
# Skipping 4I6Y_e001: Not a single-chain topology.
# Processing file: 4I71_e001
# Saved frames from 4I71_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4I8H_e001
# Saved frames from 4I8H_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4I9O_e001
# Saved frames from 4I9O_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4IAU_e001
# Saved frames from 4IAU_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4IKV_e001
# Saved frames from 4IKV_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4IUJ_e001
# Saved frames from 4IUJ_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4IXN_e001
# Skipping 4IXN_e001: Not a single-chain topology.
# Processing file: 4IYA_e001
# Saved frames from 4IYA_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4J9Y_e001
# Skipping 4J9Y_e001: Not a single-chain topology.
# Processing file: 4JBU_e001
# Saved frames from 4JBU_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4JCC_e001
# Saved frames from 4JCC_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4JER_e001
# Saved frames from 4JER_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4JK8_e001
# Skipping 4JK8_e001: Not a single-chain topology.
# Processing file: 4JXQ_e001
# Skipping 4JXQ_e001: Not a single-chain topology.
# Processing file: 4K8G_e001
# Saved frames from 4K8G_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4KEF_e001
# Saved frames from 4KEF_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4LD8_e001
# Saved frames from 4LD8_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4LWU_e001
# Saved frames from 4LWU_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4MF5_e001
# Saved frames from 4MF5_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4N7F_e001
# Skipping 4N7F_e001: Not a single-chain topology.
# Processing file: 4N7T_e001
# Skipping 4N7T_e001: Not a single-chain topology.
# Processing file: 4N9S_e001
# Saved frames from 4N9S_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4NPD_e001
# Saved frames from 4NPD_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4O5J_e001
# Saved frames from 4O5J_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4OO8_e001
# Skipping 4OO8_e001: Not a single-chain topology.
# Processing file: 4OOX_e001
# Saved frames from 4OOX_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4P1M_e001
# Skipping 4P1M_e001: Not a single-chain topology.
# Processing file: 4P3A_e001
# Skipping 4P3A_e001: Not a single-chain topology.
# Processing file: 4P79_e001
# Saved frames from 4P79_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4PS6_e001
# Saved frames from 4PS6_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4PSY_e001
# Saved frames from 4PSY_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4QA8_e001
# Saved frames from 4QA8_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4QB0_e001
# Saved frames from 4QB0_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4QQW_e001
# Skipping 4QQW_e001: Not a single-chain topology.
# Processing file: 4R5R_e001
# Skipping 4R5R_e001: Not a single-chain topology.
# Processing file: 4SGB_e001
# Skipping 4SGB_e001: Not a single-chain topology.
# Processing file: 4TKC_e001
# Saved frames from 4TKC_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4U9H_e001
# Skipping 4U9H_e001: Not a single-chain topology.
# Processing file: 4UE8_e001
# Skipping 4UE8_e001: Not a single-chain topology.
# Processing file: 4UW2_e001
# Skipping 4UW2_e001: Not a single-chain topology.
# Processing file: 4UYB_e001
# Saved frames from 4UYB_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4W64_e001
# Skipping 4W64_e001: Not a single-chain topology.
# Processing file: 4WD8_e001
# Skipping 4WD8_e001: Not a single-chain topology.
# Processing file: 4WIQ_e001
# Saved frames from 4WIQ_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4WPK_e001
# Saved frames from 4WPK_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4WSB_e001
# Skipping 4WSB_e001: Not a single-chain topology.
# Processing file: 4WWX_e001
# Skipping 4WWX_e001: Not a single-chain topology.
# Processing file: 4X9X_e001
# Saved frames from 4X9X_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4XFM_e001
# Saved frames from 4XFM_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 4XGA_e001
# Skipping 4XGA_e001: Not a single-chain topology.
# Processing file: 4YPO_e001
# Skipping 4YPO_e001: Not a single-chain topology.
# Processing file: 4ZH7_e001
# Saved frames from 4ZH7_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5AE0_e001
# Saved frames from 5AE0_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5AZP_e001
# Skipping 5AZP_e001: Not a single-chain topology.
# Processing file: 5B5E_e001
# Skipping 5B5E_e001: Not a single-chain topology.
# Processing file: 5BQ9_e001
# Skipping 5BQ9_e001: Not a single-chain topology.
# Processing file: 5BR4_e001
# Skipping 5BR4_e001: Not a single-chain topology.
# Processing file: 5C6N_e001
# Saved frames from 5C6N_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5CKL_e001
# Saved frames from 5CKL_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5D8V_e001
# Saved frames from 5D8V_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5FBF_e001
# Saved frames from 5FBF_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5FYZ_e001
# Saved frames from 5FYZ_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5GMK_e001
# Skipping 5GMK_e001: Not a single-chain topology.
# Processing file: 5GMZ_e001
# Skipping 5GMZ_e001: Not a single-chain topology.
# Processing file: 5GV0_e001
# Saved frames from 5GV0_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5I1M_e001
# Saved frames from 5I1M_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5ID6_e001
# Skipping 5ID6_e001: Not a single-chain topology.
# Processing file: 5IG6_e001
# Saved frames from 5IG6_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5II8_e001
# Saved frames from 5II8_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5K2L_e001
# Saved frames from 5K2L_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5KTN_e001
# Saved frames from 5KTN_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5LJ3_e001
# Skipping 5LJ3_e001: Not a single-chain topology.
# Processing file: 5M1E_e001
# Skipping 5M1E_e001: Not a single-chain topology.
# Processing file: 5MUX_e001
# Skipping 5MUX_e001: Not a single-chain topology.
# Processing file: 5NCG_e001
# Skipping 5NCG_e001: Not a single-chain topology.
# Processing file: 5NJC_e001
# Skipping 5NJC_e001: Not a single-chain topology.
# Processing file: 5NW3_e001
# Saved frames from 5NW3_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5R0D_e001
# Skipping 5R0D_e001: Not a single-chain topology.
# Processing file: 5SYB_e001
# Skipping 5SYB_e001: Not a single-chain topology.
# Processing file: 5U3A_e001
# Saved frames from 5U3A_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5WOP_e001
# Skipping 5WOP_e001: Not a single-chain topology.
# Processing file: 5XBX_e001
# Saved frames from 5XBX_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5XVT_e001
# Saved frames from 5XVT_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5XZ7_e001
# Saved frames from 5XZ7_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5ZIO_e001
# Saved frames from 5ZIO_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 5ZRT_e001
# Skipping 5ZRT_e001: Not a single-chain topology.
# Processing file: 5ZW7_e001
# Saved frames from 5ZW7_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6BPL_e001
# Skipping 6BPL_e001: Not a single-chain topology.
# Processing file: 6BXD_e001
# Saved frames from 6BXD_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6CBR_e001
# Skipping 6CBR_e001: Not a single-chain topology.
# Processing file: 6DCM_e001
# Saved frames from 6DCM_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6E6O_e001
# Saved frames from 6E6O_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6E85_e001
# Skipping 6E85_e001: Not a single-chain topology.
# Processing file: 6FGC_e001
# Saved frames from 6FGC_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6FRE_e001
# Saved frames from 6FRE_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6G6K_e001
# Skipping 6G6K_e001: Not a single-chain topology.
# Processing file: 6GKX_e001
# Saved frames from 6GKX_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6GX2_e001
# Saved frames from 6GX2_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6HN1_e001
# Saved frames from 6HN1_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6HR4_e001
# Saved frames from 6HR4_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6HS4_e001
# Skipping 6HS4_e001: Not a single-chain topology.
# Processing file: 6I0I_e001
# Skipping 6I0I_e001: Not a single-chain topology.
# Processing file: 6ID0_e001
# Skipping 6ID0_e001: Not a single-chain topology.
# Processing file: 6IGG_e001
# Saved frames from 6IGG_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6L27_e001
# Saved frames from 6L27_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6L8G_e001
# Skipping 6L8G_e001: Not a single-chain topology.
# Processing file: 6LPH_e001
# Skipping 6LPH_e001: Not a single-chain topology.
# Processing file: 6LUJ_e001
# Skipping 6LUJ_e001: Not a single-chain topology.
# Processing file: 6LY5_e001
# Skipping 6LY5_e001: Not a single-chain topology.
# Processing file: 6MU0_e001
# Saved frames from 6MU0_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6N59_e001
# Saved frames from 6N59_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6NP3_e001
# Saved frames from 6NP3_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6P2L_e001
# Saved frames from 6P2L_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6PQK_e001
# Skipping 6PQK_e001: Not a single-chain topology.
# Processing file: 6PR1_e001
# Skipping 6PR1_e001: Not a single-chain topology.
# Processing file: 6R2W_e001
# Skipping 6R2W_e001: Not a single-chain topology.
# Processing file: 6RKG_e001
# Skipping 6RKG_e001: Not a single-chain topology.
# Processing file: 6RVQ_e001
# Saved frames from 6RVQ_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6RYN_e001
# Saved frames from 6RYN_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6S2M_e001
# Saved frames from 6S2M_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6S6C_e001
# Saved frames from 6S6C_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6S6F_e001
# Skipping 6S6F_e001: Not a single-chain topology.
# Processing file: 6SU5_e001
# Saved frames from 6SU5_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6T6K_e001
# Saved frames from 6T6K_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6TGU_e001
# Saved frames from 6TGU_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6THV_e001
# Saved frames from 6THV_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6TIT_e001
# Saved frames from 6TIT_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6TRJ_e001
# Saved frames from 6TRJ_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6U26_e001
# Skipping 6U26_e001: Not a single-chain topology.
# Processing file: 6U66_e001
# Skipping 6U66_e001: Not a single-chain topology.
# Processing file: 6U6S_e001
# Skipping 6U6S_e001: Not a single-chain topology.
# Processing file: 6ULL_e001
# Saved frames from 6ULL_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6UXE_e001
# Skipping 6UXE_e001: Not a single-chain topology.
# Processing file: 6V1C_e001
# Saved frames from 6V1C_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6V9M_e001
# Skipping 6V9M_e001: Not a single-chain topology.
# Processing file: 6VG5_e001
# Skipping 6VG5_e001: Not a single-chain topology.
# Processing file: 6VK6_e001
# Skipping 6VK6_e001: Not a single-chain topology.
# Processing file: 6WE8_e001
# Skipping 6WE8_e001: Not a single-chain topology.
# Processing file: 6WLC_e001
# Skipping 6WLC_e001: Not a single-chain topology.
# Processing file: 6XAW_e001
# Skipping 6XAW_e001: Not a single-chain topology.
# Processing file: 6XIP_e001
# Skipping 6XIP_e001: Not a single-chain topology.
# Processing file: 6Y3B_e001
# Skipping 6Y3B_e001: Not a single-chain topology.
# Processing file: 6YHM_e001
# Saved frames from 6YHM_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6Z3T_e001
# Skipping 6Z3T_e001: Not a single-chain topology.
# Processing file: 6Z4U_e001
# Skipping 6Z4U_e001: Not a single-chain topology.
# Processing file: 6ZCO_e001
# Saved frames from 6ZCO_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 6ZK9_e001
# Skipping 6ZK9_e001: Not a single-chain topology.
# Processing file: 6ZPE_e001
# Saved frames from 6ZPE_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 7ACC_e001
# Skipping 7ACC_e001: Not a single-chain topology.
# Processing file: 7AHK_e001
# Saved frames from 7AHK_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 7B1S_e001
# Skipping 7B1S_e001: Not a single-chain topology.
# Processing file: 7BZK_e001
# Skipping 7BZK_e001: Not a single-chain topology.
# Processing file: 7C8N_e001
# Saved frames from 7C8N_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 7COH_e001
# Skipping 7COH_e001: Not a single-chain topology.
# Processing file: 7DKZ_e001
# Skipping 7DKZ_e001: Not a single-chain topology.
# Processing file: 7EAM_e001
# Skipping 7EAM_e001: Not a single-chain topology.
# Processing file: 7EQ4_e001
# Saved frames from 7EQ4_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 7JFL_e001
# Skipping 7JFL_e001: Not a single-chain topology.
# Processing file: 7JGW_e001
# Saved frames from 7JGW_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 7JJK_e001
# Saved frames from 7JJK_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 7K3K_e001
# Skipping 7K3K_e001: Not a single-chain topology.
# Processing file: 7KJG_e001
# Saved frames from 7KJG_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 7KR0_e001
# Saved frames from 7KR0_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 7KRI_e001
# Skipping 7KRI_e001: Not a single-chain topology.
# Processing file: 7LVS_e001
# Skipping 7LVS_e001: Not a single-chain topology.
# Processing file: 7M3P_e001
# Skipping 7M3P_e001: Not a single-chain topology.
# Processing file: 7MTO_e001
# Saved frames from 7MTO_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 7NDY_e001
# Skipping 7NDY_e001: Not a single-chain topology.
# Processing file: 7NIY_e001
# Saved frames from 7NIY_e001 to output/pdbs_traj/SCOPe_single_frame
# Processing file: 7O74_e001
# Skipping 7O74_e001: Not a single-chain topology.
# Processing completed.
# The following files were skipped due to errors: ['output/pdbs_traj/SCOPe/.ipynb_checkpoints/d1b7ca_-checkpoint.pdb', 'output/pdbs_traj/SCOPe/.ipynb_checkpoints/d1oaia_-checkpoint.pdb']

# %% [markdown]
# ## Only save lines starting with 'ATOM' and skip hydrogen atoms

# %%
# Go through folder and delete all lines from folders that don't start with \"ATOM\"\n",
files = sorted([f for f in os.listdir('/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/SCOPe_single_frame') if os.path.isfile(os.path.join('/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/SCOPe_single_frame',f))and not f.startswith('.')])
for file_name in files:
    file_path = os.path.join('/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/SCOPe_single_frame', file_name)
    with open(file_path, 'r') as file:
        lines = [
            line for line in file
            if line.startswith("ATOM") and not line[12:16].strip().startswith("H")
        ]
    
    with open(file_path, 'w') as file:
        file.writelines(lines)

# %% [markdown]
# ## Renumber residues

# %%
# Renumber the residue numbers in pdb files usning function
folder_path = '/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/SCOPe_single_frame'
start_residue_number = 1
renumber_residues(folder_path, start_residue_number)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 folder_path = '/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/SCOPe_single_frame'
#       3 start_residue_number = 1
# ----> 4 renumber_residues(folder_path, start_residue_number)
#
# NameError: name 'renumber_residues' is not defined

# %% [markdown]
# ## Copy files to Protein_CT/input/pdb/

# %% [markdown]
# Only run this piece of code when you want to export PBD files to protein_CT/input_files/pdb/

# %%
#If folder does not exist, create folder
if not os.path.isdir('/Users/murielhammond/RP1/CT_code/Protein_CT/input_files/pdb'): os.makedirs('/Users/murielhammond/RP1/CT_code/Protein_CT/input_files/pdb')

#Copy pdb files to /Protein_CT/input_files/pdb
for num,files in enumerate(os.listdir('/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/SCOPe_single_frame')):
    if files.endswith(('cif','pdb')):
        trajectory_PDB_files_preparation_path = os.path.join('/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/SCOPe_single_frame', files)
        trajectory_protein_CT_path = '/Users/murielhammond/RP1/CT_code/Protein_CT/input_files/pdb'
        shutil.copy(trajectory_PDB_files_preparation_path, trajectory_protein_CT_path)
