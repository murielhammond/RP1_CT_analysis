# %% [markdown]
# # Preprocess ACPRO data into PDB files

# %% [markdown]
# PDB files from the ACPRO database (url : https://www.ats.amherst.edu/protein/) are downloaded as .gz files. They are unzipped,
# the hydrogen atoms are removed from the files and only the lines not starting with 'ATOM' are  removed. After, residues are renumbered and only single chain topology files are used.
# ACPRO_df is created with folding and unfolding rate data which can also be found on the ACPRO site. This is needed later in the project.
#
# Data is saved in the CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame and can be copied to the protein_CT/input folder by running the last block of code.

# %% [markdown]
# ## Importing and downloading KPRO data

# %%
import pandas as pd
import requests
import os
import gzip
import mdtraj
import tarfile
import shutil
from requests import get
import numpy as np

# %% [markdown]
# ## Function to renumber residues

# %%
def renumber_residues(folder_path, start_residue_number):
#Function to renumber all incorrectly numbered residues from trajectory folder. 
    for filename in os.listdir(folder_path):
        if filename.endswith('.pdb'):
            input_pdb = os.path.join(folder_path, filename)
    
            with open(input_pdb, 'r') as infile:
                lines = infile.readlines()
            
            # Check the residue number in the first ATOM/HETATM line
            first_residue_number = None
            for line in lines:
                if line.startswith(("ATOM", "HETATM")):
                    first_residue_number = int(line[22:26].strip())
                    break
            
            # Only proceed with renumbering if the first residue is 9999 (-1) or 0
            if first_residue_number != 1:
                with open(input_pdb, 'w') as outfile:
                    current_residue_number = start_residue_number
                    last_residue_id = None
                    first_residue = True  # Flag to handle the first residue separately

                    for line in lines:
                        # Only renumber residue information in ATOM/HETATM records
                        if line.startswith(("ATOM", "HETATM")):
                            residue_id = line[22:26].strip()

                            # Check if we're on a new residue
                            if residue_id != last_residue_id:
                                last_residue_id = residue_id
                                # Increment only after the first residue
                                if not first_residue:
                                    current_residue_number += 1
                                first_residue = False  # Set flag to False after first residue

                            # Replace residue number in the line
                            new_line = (
                                line[:22] +
                                "{:4}".format(current_residue_number) +  # Format the new residue number
                                line[26:]
                            )
                            outfile.write(new_line)
                        else:
                            # Write non-ATOM/HETATM lines as is
                            outfile.write(line)
        
                print("Residues renumbered successfully in {}".format(input_pdb))
            else:
                print("Skipped renumbering for {} (first residue is already 1)".format(filename))

# %% [markdown]
# ## Make a list of all PDB id's from ACPRO database to download the pdb file from PDB bank

# %% [markdown]
# PDB files are manually downloaded from: https://www.rcsb.org/downloads using the list of PDB id's. The files are manually downloaded as .gz and code below is to unzip these files.

# %%
# Specify file_path
file_path = "/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/ACPRO_data/ACPRO_data_list.csv"

# Read the TSV file into a DataFrame
full_df = pd.read_csv(file_path)

ACPRO_list = full_df['PDB Id']
ACPRO_list = set(ACPRO_list)
ACPRO_list
# Out:
# {'1A6N',
#  '1ADW',
#  '1AON',
#  '1APS',
#  '1ARR',
#  '1AU7',
#  '1AUE',
#  '1AVZ',
#  '1AYI',
#  '1B9C',
#  '1BA5',
#  '1BD8',
#  '1BF4',
#  '1BFE',
#  '1BNI',
#  '1BNZ',
#  '1BRS',
#  '1C9O',
#  '1CDC',
#  '1CSP',
#  '1CUN',
#  '1DIV',
#  '1E0G',
#  '1E0L',
#  '1E0M',
#  '1E41',
#  '1E65',
#  '1EAL',
#  '1EHB',
#  '1ENH',
#  '1FEX',
#  '1FKF',
#  '1FMK',
#  '1FNF',
#  '1FTG',
#  '1G6P',
#  '1GM1',
#  '1GXT',
#  '1HCD',
#  '1HEL',
#  '1HMK',
#  '1HRC',
#  '1I1B',
#  '1IDY',
#  '1IMQ',
#  '1J5U',
#  '1JMQ',
#  '1JO8',
#  '1JON',
#  '1JOO',
#  '1K0S',
#  '1K85',
#  '1K8M',
#  '1L2Y',
#  '1L8W',
#  '1LMB',
#  '1LOP',
#  '1M9S',
#  '1MJC',
#  '1N88',
#  '1NPS',
#  '1NTI',
#  '1O6X',
#  '1PBA',
#  '1PGB',
#  '1PHP',
#  '1PIN',
#  '1PNJ',
#  '1POH',
#  '1PRB',
#  '1PRS',
#  '1PSF',
#  '1QOP',
#  '1QTU',
#  '1RA9',
#  '1RFA',
#  '1RIS',
#  '1RYK',
#  '1SCE',
#  '1SHG',
#  '1SPR',
#  '1SRL',
#  '1SS1',
#  '1ST7',
#  '1TEN',
#  '1TIT',
#  '1TTF',
#  '1U5P',
#  '1UBQ',
#  '1URN',
#  '1UZC',
#  '1V9E',
#  '1VII',
#  '1W4J',
#  '1WIT',
#  '1YCC',
#  '1YEA',
#  '1YZA',
#  '256B',
#  '2A3D',
#  '2A5E',
#  '2ACY',
#  '2BLM',
#  '2CI2',
#  '2CRO',
#  '2EAL',
#  '2FDQ',
#  '2HPR',
#  '2HQI',
#  '2LZM',
#  '2PDD',
#  '2PTL',
#  '2QJL',
#  '2RN2',
#  '2VIK',
#  '2VKN',
#  '2WXC',
#  '3CHY',
#  '3F6R',
#  '3M48'}

# %% [markdown]
# ## Preprocessing PDB files

# %%
path_targzs = '/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/ACPRO_data/ACPRO_gz'
list_targzs = sorted([f for f in os.listdir(path_targzs) if os.path.isfile(os.path.join(path_targzs, f)) and not f.startswith('.')])

# %%
input_folder = "/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/ACPRO_data/ACPRO_gz"
output_folder = "/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/ACPRO_data/ACPRO_pdb"
os.makedirs(output_folder, exist_ok=True)

for file_name in os.listdir(input_folder):
    if file_name.endswith(".pdb.gz"):
        input_path = os.path.join(input_folder, file_name)
        output_file_name = file_name[:-3]
        output_path = os.path.join(output_folder, output_file_name)

        # Decompress the file
        with gzip.open(input_path, 'rb') as gz_file:
            with open(output_path, 'wb') as output_file:
                shutil.copyfileobj(gz_file, output_file)

# %%
# Make list of the PED in folder pdbs and loop through this list
root = 'output/ACPRO_data/ACPRO_pdb'
list_KPRO = []
for path, subdirs, files in os.walk(root):
    for name in files:
        if name.endswith('.pdb'):
            list_KPRO.append(os.path.join(path, name))

list_KPRO.sort()
list_KPRO
# Out:
# ['output/ACPRO_data/ACPRO_pdb/1a6n.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1adw.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1aon.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1aps.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1arr.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1au7.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1aue.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1avz.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1ayi.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1b9c.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1ba5.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1bd8.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1bf4.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1bfe.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1bni.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1bnz.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1brs.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1c9o.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1cdc.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1csp.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1cun.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1div.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1e0g.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1e0l.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1e0m.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1e41.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1e65.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1eal.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1ehb.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1enh.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1fex.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1fkf.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1fmk.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1fnf.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1ftg.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1g6p.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1gm1.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1gxt.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1hcd.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1hel.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1hmk.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1hrc.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1i1b.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1idy.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1imq.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1j5u.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1jmq.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1jo8.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1jon.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1joo.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1k0s.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1k85.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1k8m.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1l2y.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1l8w.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1lmb.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1lop.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1m9s.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1mjc.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1n88.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1nps.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1nti.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1o6x.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1pba.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1pgb.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1php.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1pin.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1pnj.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1poh.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1prb.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1prs.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1psf.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1qop.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1qtu.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1ra9.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1rfa.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1ris.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1ryk.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1sce.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1shg.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1spr.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1srl.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1ss1.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1st7.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1ten.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1tit.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1ttf.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1u5p.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1ubq.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1urn.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1uzc.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1v9e.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1vii.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1w4j.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1wit.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1ycc.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1yea.pdb',
#  'output/ACPRO_data/ACPRO_pdb/1yza.pdb',
#  'output/ACPRO_data/ACPRO_pdb/256b.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2a3d.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2a5e.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2acy.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2blm.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2ci2.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2cro.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2eal.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2fdq.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2hpr.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2hqi.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2lzm.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2pdd.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2ptl.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2qjl.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2rn2.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2vik.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2vkn.pdb',
#  'output/ACPRO_data/ACPRO_pdb/2wxc.pdb',
#  'output/ACPRO_data/ACPRO_pdb/3chy.pdb',
#  'output/ACPRO_data/ACPRO_pdb/3f6r.pdb',
#  'output/ACPRO_data/ACPRO_pdb/3m48.pdb']

# %% [markdown]
# ## Filter on single chain and < 200 frames

# %%
exception_list = []
# Make a new folder for PED.pdb trajectories
output_dir = 'output/pdbs_traj/ACPRO_single_frame'
if not os.path.isdir(output_dir):
    os.makedirs(output_dir)

# Process each PDB trajectory file
for pdb in list_KPRO:
    try:
        # Define the base name for saving frames
        base_name = os.path.basename(pdb)[:-4] + "_e001"

        # Check if the first frame already exists to avoid redundant processing
        if not os.path.isfile(f'{output_dir}/{base_name}.0.pdb'):
            print(f"Processing file: {base_name}")

            # Load the trajectory
            traj = mdtraj.load(pdb)

            # Check if the trajectory has less than 200 frames
            if traj.n_frames < 200:
                # Ensure it's a single-chain topology before saving frames
                if traj.topology.n_chains == 1:
                    current_segment = []
                    frame_index = 0

                    # Read the PDB content
                    with open(pdb, 'r') as file:
                        pdb_content = file.readlines()

                    # Split the PDB file into frames based on atom serial resets
                    for line in pdb_content:
                        if line.startswith("ATOM") or line.startswith("HETATM"):
                            # Extract the atom serial number
                            serial_number = int(line[6:11].strip())
                            if serial_number == 1 and current_segment:
                                # Save the completed segment to a new file
                                output_file = os.path.join(output_dir, f"{base_name}.{frame_index}.pdb")
                                with open(output_file, 'w') as frame_file:
                                    frame_file.writelines(current_segment)
                                frame_index += 1
                                current_segment = []

                        current_segment.append(line)

                    # Save the last segment if it exists
                    if current_segment:
                        output_file = os.path.join(output_dir, f"{base_name}.{frame_index}.pdb")
                        with open(output_file, 'w') as frame_file:
                            frame_file.writelines(current_segment)

                    print(f"Saved frames from {base_name} to {output_dir}")
                else:
                    print(f"Skipping {base_name}: Not a single-chain topology.")
            else:
                print(f"Skipping {base_name}: Contains {traj.n_frames} frames (exceeds limit).")
    except Exception as e:
        print(f"File {os.path.basename(pdb)} is skipped due to error: {e}")
        exception_list.append(pdb)

print("Processing completed.")
if exception_list:
    print(f"The following files were skipped due to errors: {exception_list}")
# Out:
# Processing file: 1a6n_e001
# Saved frames from 1a6n_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1adw_e001
# Skipping 1adw_e001: Not a single-chain topology.
# Processing file: 1aon_e001
# Skipping 1aon_e001: Not a single-chain topology.
# Processing file: 1aps_e001
# Saved frames from 1aps_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1arr_e001
# Skipping 1arr_e001: Not a single-chain topology.
# Processing file: 1au7_e001
# Skipping 1au7_e001: Not a single-chain topology.
# Processing file: 1aue_e001
# Skipping 1aue_e001: Not a single-chain topology.
# Processing file: 1avz_e001
# Skipping 1avz_e001: Not a single-chain topology.
# Processing file: 1ayi_e001
# Saved frames from 1ayi_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1b9c_e001
# Skipping 1b9c_e001: Not a single-chain topology.
# Processing file: 1ba5_e001
# Saved frames from 1ba5_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1bd8_e001
# Saved frames from 1bd8_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1bf4_e001
# Skipping 1bf4_e001: Not a single-chain topology.
# Processing file: 1bfe_e001
# Saved frames from 1bfe_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1bni_e001
# Skipping 1bni_e001: Not a single-chain topology.
# Processing file: 1bnz_e001
# Skipping 1bnz_e001: Not a single-chain topology.
# Processing file: 1brs_e001
# Skipping 1brs_e001: Not a single-chain topology.
# Processing file: 1c9o_e001
# Skipping 1c9o_e001: Not a single-chain topology.
# Processing file: 1cdc_e001
# Skipping 1cdc_e001: Not a single-chain topology.
# Processing file: 1csp_e001
# Saved frames from 1csp_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1cun_e001
# Skipping 1cun_e001: Not a single-chain topology.
# Processing file: 1div_e001
# Saved frames from 1div_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1e0g_e001
# Saved frames from 1e0g_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1e0l_e001
# Saved frames from 1e0l_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1e0m_e001
# Saved frames from 1e0m_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1e41_e001
# Saved frames from 1e41_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1e65_e001
# Skipping 1e65_e001: Not a single-chain topology.
# Processing file: 1eal_e001
# Saved frames from 1eal_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1ehb_e001
# Saved frames from 1ehb_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1enh_e001
# Saved frames from 1enh_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1fex_e001
# Saved frames from 1fex_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1fkf_e001
# Saved frames from 1fkf_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1fmk_e001
# Saved frames from 1fmk_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1fnf_e001
# Saved frames from 1fnf_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1ftg_e001
# Saved frames from 1ftg_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1g6p_e001
# Saved frames from 1g6p_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1gm1_e001
# Saved frames from 1gm1_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1gxt_e001
# Saved frames from 1gxt_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1hcd_e001
# Saved frames from 1hcd_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1hel_e001
# Saved frames from 1hel_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1hmk_e001
# Saved frames from 1hmk_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1hrc_e001
# Saved frames from 1hrc_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1i1b_e001
# Saved frames from 1i1b_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1idy_e001
# Saved frames from 1idy_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1imq_e001
# Saved frames from 1imq_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1j5u_e001
# Saved frames from 1j5u_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1jmq_e001
# Skipping 1jmq_e001: Not a single-chain topology.
# Processing file: 1jo8_e001
# Saved frames from 1jo8_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1jon_e001
# Saved frames from 1jon_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1joo_e001
# Saved frames from 1joo_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1k0s_e001
# Saved frames from 1k0s_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1k85_e001
# Saved frames from 1k85_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1k8m_e001
# Saved frames from 1k8m_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1l2y_e001
# Saved frames from 1l2y_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1l8w_e001
# Skipping 1l8w_e001: Not a single-chain topology.
# Processing file: 1lmb_e001
# Skipping 1lmb_e001: Not a single-chain topology.
# Processing file: 1lop_e001
# Skipping 1lop_e001: Not a single-chain topology.
# Processing file: 1m9s_e001
# Saved frames from 1m9s_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1mjc_e001
# Saved frames from 1mjc_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1n88_e001
# Saved frames from 1n88_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1nps_e001
# Saved frames from 1nps_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1nti_e001
# Saved frames from 1nti_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1o6x_e001
# Saved frames from 1o6x_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1pba_e001
# Saved frames from 1pba_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1pgb_e001
# Saved frames from 1pgb_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1php_e001
# Saved frames from 1php_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1pin_e001
# Saved frames from 1pin_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1pnj_e001
# Saved frames from 1pnj_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1poh_e001
# Saved frames from 1poh_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1prb_e001
# Saved frames from 1prb_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1prs_e001
# Saved frames from 1prs_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1psf_e001
# Saved frames from 1psf_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1qop_e001
# Skipping 1qop_e001: Not a single-chain topology.
# Processing file: 1qtu_e001
# Saved frames from 1qtu_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1ra9_e001
# Saved frames from 1ra9_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1rfa_e001
# Saved frames from 1rfa_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1ris_e001
# Saved frames from 1ris_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1ryk_e001
# Saved frames from 1ryk_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1sce_e001
# Skipping 1sce_e001: Not a single-chain topology.
# Processing file: 1shg_e001
# Saved frames from 1shg_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1spr_e001
# Skipping 1spr_e001: Not a single-chain topology.
# Processing file: 1srl_e001
# Saved frames from 1srl_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1ss1_e001
# Saved frames from 1ss1_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1st7_e001
# Saved frames from 1st7_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1ten_e001
# Saved frames from 1ten_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1tit_e001
# Saved frames from 1tit_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1ttf_e001
# Saved frames from 1ttf_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1u5p_e001
# Saved frames from 1u5p_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1ubq_e001
# Saved frames from 1ubq_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1urn_e001
# Skipping 1urn_e001: Not a single-chain topology.
# Processing file: 1uzc_e001
# Saved frames from 1uzc_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1v9e_e001
# Skipping 1v9e_e001: Not a single-chain topology.
# Processing file: 1vii_e001
# Saved frames from 1vii_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1w4j_e001
# Saved frames from 1w4j_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1wit_e001
# Saved frames from 1wit_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1ycc_e001
# Saved frames from 1ycc_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1yea_e001
# Saved frames from 1yea_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 1yza_e001
# Saved frames from 1yza_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 256b_e001
# Skipping 256b_e001: Not a single-chain topology.
# Processing file: 2a3d_e001
# Saved frames from 2a3d_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 2a5e_e001
# Saved frames from 2a5e_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 2acy_e001
# Saved frames from 2acy_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 2blm_e001
# Skipping 2blm_e001: Not a single-chain topology.
# Processing file: 2ci2_e001
# Saved frames from 2ci2_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 2cro_e001
# Saved frames from 2cro_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 2eal_e001
# Skipping 2eal_e001: Not a single-chain topology.
# Processing file: 2fdq_e001
# Skipping 2fdq_e001: Not a single-chain topology.
# Processing file: 2hpr_e001
# Saved frames from 2hpr_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 2hqi_e001
# Saved frames from 2hqi_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 2lzm_e001
# Saved frames from 2lzm_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 2pdd_e001
# Saved frames from 2pdd_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 2ptl_e001
# Saved frames from 2ptl_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 2qjl_e001
# Saved frames from 2qjl_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 2rn2_e001
# Saved frames from 2rn2_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 2vik_e001
# Saved frames from 2vik_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 2vkn_e001
# Skipping 2vkn_e001: Not a single-chain topology.
# Processing file: 2wxc_e001
# Saved frames from 2wxc_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 3chy_e001
# Saved frames from 3chy_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing file: 3f6r_e001
# Skipping 3f6r_e001: Not a single-chain topology.
# Processing file: 3m48_e001
# Saved frames from 3m48_e001 to output/pdbs_traj/ACPRO_single_frame
# Processing completed.

# %% [markdown]
# ## Only save lines starting with 'ATOM' and skip hydrogen atoms

# %%
# Go through folder and delete all lines from folders that don't start with \"ATOM\"\n",
files = sorted([f for f in os.listdir('/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/ACPRO_data/ACPRO_pdb/') if os.path.isfile(os.path.join('/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/ACPRO_data/ACPRO_pdb/',f)) and not f.startswith('.')])

for file_name in files:
    file_path = os.path.join('/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/ACPRO_data/ACPRO_pdb/', file_name)
    with open(file_path, 'r') as file:
        lines = [
            line for line in file
            if line.startswith("ATOM") and not line[12:16].strip().startswith("H")
        ]
        
    with open(file_path, 'w') as file:
        file.writelines(lines)

# %% [markdown]
# ## Renumber the residues

# %%
# Renumber the residue numbers in pdb files
folder_path = '/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame'
start_residue_number = 1
renumber_residues(folder_path, start_residue_number)
# Out:
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1e41_e001.21.pdb
# Skipped renumbering for 1l2y_e001.4.pdb (first residue is already 1)
# Skipped renumbering for 1imq_e001.0.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1gm1_e001.22.pdb
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1fmk_e001.0.pdb
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1uzc_e001.16.pdb
# Skipped renumbering for 1pba_e001.13.pdb (first residue is already 1)
# Skipped renumbering for 1n88_e001.17.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1uzc_e001.9.pdb
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1ss1_e001.16.pdb
# Skipped renumbering for 1n88_e001.2.pdb (first residue is already 1)
# Skipped renumbering for 1prs_e001.11.pdb (first residue is already 1)
# Skipped renumbering for 1aps_e001.2.pdb (first residue is already 1)
# Skipped renumbering for 1l2y_e001.19.pdb (first residue is already 1)
# Skipped renumbering for 1l2y_e001.31.pdb (first residue is already 1)
# Skipped renumbering for 1l2y_e001.25.pdb (first residue is already 1)
# Skipped renumbering for 1joo_e001.0.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1rfa_e001.10.pdb
# Skipped renumbering for 1ttf_e001.4.pdb (first residue is already 1)
# Skipped renumbering for 1psf_e001.0.pdb (first residue is already 1)
# Skipped renumbering for 1e0m_e001.7.pdb (first residue is already 1)
# Skipped renumbering for 1e0m_e001.6.pdb (first residue is already 1)
# Skipped renumbering for 1ttf_e001.5.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1rfa_e001.11.pdb
# Skipped renumbering for 1l2y_e001.24.pdb (first residue is already 1)
# Skipped renumbering for 1l2y_e001.30.pdb (first residue is already 1)
# Skipped renumbering for 1l2y_e001.18.pdb (first residue is already 1)
# Skipped renumbering for 1aps_e001.3.pdb (first residue is already 1)
# Skipped renumbering for 1prs_e001.10.pdb (first residue is already 1)
# Skipped renumbering for 1n88_e001.3.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1ss1_e001.17.pdb
# Skipped renumbering for 1n88_e001.16.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1uzc_e001.8.pdb
# Skipped renumbering for 1pba_e001.12.pdb (first residue is already 1)
# Skipped renumbering for 1hcd_e001.0.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1uzc_e001.17.pdb
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1gm1_e001.23.pdb
# Skipped renumbering for 1l2y_e001.5.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1e41_e001.20.pdb
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1e41_e001.22.pdb
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1gm1_e001.21.pdb
# Skipped renumbering for 1l2y_e001.7.pdb (first residue is already 1)
# Skipped renumbering for 1yza_e001.8.pdb (first residue is already 1)
# Skipped renumbering for 2pdd_e001.8.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1uzc_e001.15.pdb
# Skipped renumbering for 1e0g_e001.18.pdb (first residue is already 1)
# Skipped renumbering for 1n88_e001.14.pdb (first residue is already 1)
# Skipped renumbering for 1pba_e001.10.pdb (first residue is already 1)
# Skipped renumbering for 1n88_e001.28.pdb (first residue is already 1)
# Skipped renumbering for 1n88_e001.1.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1ss1_e001.15.pdb
# Skipped renumbering for 1prs_e001.12.pdb (first residue is already 1)
# Skipped renumbering for 1o6x_e001.8.pdb (first residue is already 1)
# Skipped renumbering for 1aps_e001.1.pdb (first residue is already 1)
# Skipped renumbering for 1l2y_e001.26.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/2wxc_e001.9.pdb
# Skipped renumbering for 1l2y_e001.32.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1rfa_e001.13.pdb
# Skipped renumbering for 1e0m_e001.4.pdb (first residue is already 1)
# Skipped renumbering for 1ttf_e001.7.pdb (first residue is already 1)
# Skipped renumbering for 1ttf_e001.6.pdb (first residue is already 1)
# Skipped renumbering for 1e0m_e001.5.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1rfa_e001.12.pdb
# Skipped renumbering for 1l2y_e001.33.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/2wxc_e001.8.pdb
# Skipped renumbering for 1l2y_e001.27.pdb (first residue is already 1)
# Skipped renumbering for 1aps_e001.0.pdb (first residue is already 1)
# Skipped renumbering for 1o6x_e001.9.pdb (first residue is already 1)
# Skipped renumbering for 1prs_e001.13.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1pin_e001.0.pdb
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1srl_e001.0.pdb
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1ss1_e001.14.pdb
# Skipped renumbering for 1n88_e001.0.pdb (first residue is already 1)
# Skipped renumbering for 1pba_e001.11.pdb (first residue is already 1)
# Skipped renumbering for 1e0g_e001.19.pdb (first residue is already 1)
# Skipped renumbering for 1n88_e001.15.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1uzc_e001.14.pdb
# Skipped renumbering for 2pdd_e001.9.pdb (first residue is already 1)
# Skipped renumbering for 1ris_e001.0.pdb (first residue is already 1)
# Skipped renumbering for 1yza_e001.9.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1gm1_e001.34.pdb
# Skipped renumbering for 1l2y_e001.6.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1gm1_e001.20.pdb
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1e41_e001.23.pdb
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1gm1_e001.18.pdb
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/2ci2_e001.0.pdb
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1gm1_e001.24.pdb
# Skipped renumbering for 1l2y_e001.2.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1gm1_e001.30.pdb
# Skipped renumbering for 1ba5_e001.8.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1uzc_e001.10.pdb
# Skipped renumbering for 1n88_e001.4.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1ss1_e001.10.pdb
# Skipped renumbering for 1n88_e001.11.pdb (first residue is already 1)
# Skipped renumbering for 1pba_e001.15.pdb (first residue is already 1)
# Skipped renumbering for 1prs_e001.17.pdb (first residue is already 1)
# Skipped renumbering for 1aps_e001.4.pdb (first residue is already 1)
# Skipped renumbering for 1l2y_e001.23.pdb (first residue is already 1)
# Skipped renumbering for 1l2y_e001.37.pdb (first residue is already 1)
# Skipped renumbering for 1e0m_e001.1.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1k85_e001.8.pdb
# Skipped renumbering for 1ttf_e001.2.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1e41_e001
pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1uzc_e001.4.pdb
# Skipped renumbering for 1e0g_e001.16.pdb (first residue is already 1)
# Skipped renumbering for 1ba5_e001.3.pdb (first residue is already 1)
# Skipped renumbering for 2pdd_e001.6.pdb (first residue is already 1)
# Skipped renumbering for 1yza_e001.6.pdb (first residue is already 1)
# Skipped renumbering for 2hqi_e001.13.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1gm1_e001.13.pdb
# Skipped renumbering for 1l2y_e001.9.pdb (first residue is already 1)
# Residues renumbered successfully in /Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame/1e41_e001.10.pdb

# %% [markdown]
# ## Save pdb files to protein_CT/input/pdb

# %% [markdown]
# Only run this piece of code when you want to export PDB files to protein_CT/input_files/pdb/

# %%
#If folder does not exist, create folder
if not os.path.isdir('/Users/murielhammond/RP1/CT_code/Protein_CT/input_files/pdb'): os.makedirs('/Users/murielhammond/RP1/CT_code/Protein_CT/input_files/pdb')

#Copy pdb files to /Protein_CT/input_files/pdb
for num,files in enumerate(os.listdir('/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame')):
    if files.endswith(('cif','pdb')):
        trajectory_PDB_files_preparation_path = os.path.join('/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/pdbs_traj/ACPRO_single_frame', files)
        trajectory_protein_CT_path = '/Users/murielhammond/RP1/CT_code/Protein_CT/input_files/pdb'
        shutil.copy(trajectory_PDB_files_preparation_path, trajectory_protein_CT_path)

# %% [markdown]
# ## Saving data of every protein in dataframe

# %%
ACPRO_df = pd.read_excel('/Users/murielhammond/RP1/CT_code/PDB_files_preparation/output/ACPRO_data/ACPRO_excel_list.xlsx')
ACPRO_df['log(kf)'] = ACPRO_df['ln_kf']
ACPRO_df['log_kf_error'] = ACPRO_df['ln_kf_error']
ACPRO_df = ACPRO_df.drop(columns=['Chain', 'Name', 'Protein Length', 'Structural Class', 'pH', 'Author', 'Lab Website', 'Fragment Start', 'Unnamed: 14'])
ACPRO_df
# Out:
#       PDB Folding_Type      CO  ln_kf  ln_kf_error  Temperature(celsius)  \
# 0    1A6N        Multi  140099   1.13         0.06                  5.00
# 1    1ADW        Multi  153685   0.69          NaN                 15.00
# 2    1AON        Multi  432627   0.18         0.08                 15.00
# 3    1APS          Two  207283  -1.58         0.18                 25.00
# 4    1ARR          Two  271281   9.20          NaN                 25.00
# ..    ...          ...     ...    ...          ...                   ...
# 121  2VIK        Multi  165842  11.90         0.60                 25.00
# 122  2VKN        Multi  134658   2.11         0.23                 25.00
# 123  2WXC          Two  450322  11.20          NaN                  9.85
# 124  3CHY        Multi   11312   1.00         0.10                 25.00
# 125  3F6R        Multi   15197   3.52         0.11                 20.00
#
#      log(kf)  log_kf_error
# 0       1.13          0.06
# 1       0.69           NaN
# 2       0.18          0.08
# 3      -1.58          0.18
# 4       9.20           NaN
# ..       ...           ...
# 121    11.90          0.60
# 122     2.11          0.23
# 123    11.20           NaN
# 124     1.00          0.10
# 125     3.52          0.11
#
# [126 rows x 8 columns]

# %% [markdown]
# ## Save df as csv

# %%
# ACPRO_df.to_csv('/Users/murielhammond/RP1/CT_code/CT_analysis/Dataframes/ACPRO_folding_rate_v0')
